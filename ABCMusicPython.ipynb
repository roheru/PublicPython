# %%
from scipy.io.wavfile import read
import matplotlib.pyplot as plt
import numpy as np
import os

import os
print os.getcwd()
#wav=wave.open('furelise.wav','r')
(fs,x)=read('thunder.wav')

print x.size/float(fs)#tamaño divido entre la tasa
print sum(x)

t=(np.arange(x.size)/float(fs))
print len(t)
print len(x)
plt.plot(x)
plt.show()
print len(t)
print len(x)
# Out:
# C:\Users\roheru\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\Scripts
# 17.8524263039
# -1321015
# 393646
# 196823
# 393646
# 196823
